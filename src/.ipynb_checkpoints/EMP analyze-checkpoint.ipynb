# %%
import numpy as np
import scipy
import csv 
import pandas as pd
import warnings
from sklearn.metrics.pairwise import pairwise_distances
warnings.filterwarnings("ignore")

# library for computing JSD: https://pypi.python.org/pypi/dit
import dit
from dit.divergences import jensen_shannon_divergence

import numpy as np
from sklearn.decomposition import PCA

# %%
from biom import example_table

# %%
from biom import load_table
table = load_table('../data/emp_deblur_100bp.subset_2k.biom')

# %%
# High level Exploration: matrix information for the 2k subset

# print(table.shape)
print(table.ids())
# table.ids(axis='observation') 
table.nnz
table.get_table_density()
# Out:
# ['1734.BD.NBS1055' '1001.SKD6' '662.M22' ... '1064.G.GVR167' '2182.ZF12B'
#  '1747.DZF.6202012.RJ.soil.under.basking.site']
# 0.0031125156838897323

# %%
# filter_f = lambda values, id_, md: md['environment'] == 'A'
# env_a = normed.filter(filter_f, axis='sample', inplace=False)
# check Meta data
table.metadata(axis = 'sample')
table.metadata(axis = 'observation')
# Out:
# (defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__Bacteroidia',
#                'o__Bacteroidales',
#                'f__Prevotellaceae',
#                'g__Prevotella',
#                's__melaninogenica']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__Acidobacteria-6',
#                'o__iii1-15',
#                'f__mb2424',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Bacteroidetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__Bacteroidia',
#                'o__Bacteroidales',
#                'f__Prevotellaceae',
#                'g__Prevotella',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__WS3',
#                'c__PRR-12',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__OP8',
#                'c__OP8_1',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Elusimicrobia']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__Myxococcales',
#                'f__Polyangiaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Ruminococcaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Lachnospiraceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__OP3',
#                'c__koll11',
#                'o__GIF10',
#                'f__kpj58rc',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__Acidobacteria-5',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Christensenellaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__NB1-j',
#                'f__MND4',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea',
#                'p__[Parvarchaeota]',
#                'c__[Parvarchaea]',
#                'o__YLA114',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chlorobi',
#                'c__SJA-28',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Verrucomicrobia',
#                'c__[Pedosphaerae]',
#                'o__[Pedosphaerales]']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Gemmatales',
#                'f__Isosphaeraceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Gemmatales',
#                'f__Isosphaeraceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Gemmatales',
#                'f__Isosphaeraceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Bacilli',
#                'o__Bacillales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__Acidobacteriia',
#                'o__Acidobacteriales',
#                'f__Koribacteraceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__GN02',
#                'c__GKS2-174',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Phycisphaerae',
#                'o__MSBL9',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__[Saprospirae]',
#                'o__[Saprospirales]',
#                'f__Saprospiraceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Gemmatales',
#                'f__Gemmataceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria',
#                'o__Legionellales',
#                'f__Coxiellaceae',
#                'g__Aquicella',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__SR1',
#                'c__',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__[Chloracidobacteria]',
#                'o__RB41',
#                'f__Ellin6075',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__TK17',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Ruminococcaceae',
#                'g__Faecalibacterium',
#                's__prausnitzii']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__RB25',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae',
#                'o__A31']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__Flavobacteriia',
#                'o__Flavobacteriales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__Myxococcales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Firmicutes', 'c__Clostridia']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Rickettsiales',
#                'f__mitochondria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Verrucomicrobia',
#                'c__[Spartobacteria]',
#                'o__[Chthoniobacterales]',
#                'f__[Chthoniobacteraceae]',
#                'g__Ellin506',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria',
#                'o__Legionellales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Chloroflexi']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__Solibacteres',
#                'o__Solibacterales',
#                'f__Solibacteraceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Gracilibacteraceae',
#                'g__Gracilibacter',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__[Mogibacteriaceae]',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__DA052',
#                'o__Ellin6513',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Pirellulales',
#                'f__Pirellulaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__[Chloracidobacteria]']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__Cytophagia',
#                'o__Cytophagales',
#                'f__Flammeovirgaceae',
#                'g__JTB248',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Pirellulales',
#                'f__Pirellulaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae',
#                'o__SBR1031',
#                'f__oc28',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__KSB3']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Rhodospirillales',
#                'f__Acetobacteraceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__OM190',
#                'o__agg27',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Caulobacterales',
#                'f__Caulobacteraceae',
#                'g__Asticcacaulis',
#                's__biprosthecium']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Planctomycetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Planctomycetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__TM6',
#                'c__SJA-4',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__Myxococcales',
#                'f__Myxococcaceae',
#                'g__Anaeromyxobacter',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae',
#                'o__GCA004',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae',
#                'o__GCA004',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Cyanobacteria',
#                'c__Chloroplast',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea',
#                'p__Euryarchaeota',
#                'c__DSEG',
#                'o__ArcA07',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Pirellulales',
#                'f__Pirellulaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__FBP',
#                'c__',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea',
#                'p__Euryarchaeota',
#                'c__Thermoplasmata',
#                'o__E2',
#                'f__DHVEG-1',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__DA052',
#                'o__Ellin6513',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Betaproteobacteria',
#                'o__MND1',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__OP3',
#                'c__koll11',
#                'o__GIF10',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea',
#                'p__[Parvarchaeota]',
#                'c__[Parvarchaea]',
#                'o__YLA114',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Dehalococcoidetes',
#                'o__Dehalococcoidales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__Myxococcales',
#                'f__Myxococcaceae',
#                'g__Anaeromyxobacter',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Chloroflexi',
#                'o__[Roseiflexales]',
#                'f__[Kouleothrixaceae]']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__TK17',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Acidobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Nitrospirae',
#                'c__Nitrospira',
#                'o__Nitrospirales',
#                'f__[Thermodesulfovibrionaceae]',
#                'g__LCP-6',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__MVP-21',
#                'c__',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Rhodobacterales',
#                'f__Rhodobacteraceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae',
#                'o__A31',
#                'f__S47',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__MIZ46',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__OP3',
#                'c__BD4-9',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__OD1',
#                'c__ZB2',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Cyanobacteria',
#                'c__Chloroplast',
#                'o__Stramenopiles',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chlorobi',
#                'c__BSV26',
#                'o__VC38',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea', 'p__Euryarchaeota']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__OP8',
#                'c__OP8_1',
#                'o__SHA-124',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae',
#                'o__WCHB1-50',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__WS3',
#                'c__PRR-12',
#                'o__Sediment-1',
#                'f__PRR-10',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea',
#                'p__[Parvarchaeota]',
#                'c__[Parvarchaea]',
#                'o__WCHD3-30',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae',
#                'o__SBR1031',
#                'f__A4b',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Rhodospirillales',
#                'f__Rhodospirillaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria',
#                'o__Enterobacteriales',
#                'f__Enterobacteriaceae',
#                'g__Buchnera',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__WS3',
#                'c__PRR-12',
#                'o__Sediment-1',
#                'f__CV106',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Spirochaetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Ellin329',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Gemmatimonadetes',
#                'c__Gemmatimonadetes',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Cyanobacteria',
#                'c__Oscillatoriophycideae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Phycisphaerae',
#                'o__Phycisphaerales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae',
#                'o__H39',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__OM190',
#                'o__agg27',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Actinobacteria',
#                'c__Thermoleophilia',
#                'o__Solirubrobacterales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__Bacteroidia',
#                'o__Bacteroidales',
#                'f__Marinilabiaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Chloroflexi']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Lachnospiraceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Actinobacteria',
#                'c__Actinobacteria',
#                'o__Actinomycetales',
#                'f__Kineosporiaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Cyanobacteria',
#                'c__Oscillatoriophycideae',
#                'o__Chroococcales',
#                'f__Xenococcaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__OP11',
#                'c__WCHB1-64',
#                'o__d153',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Actinobacteria',
#                'c__Thermoleophilia',
#                'o__Solirubrobacterales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__OS-K',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__WS3',
#                'c__PRR-12',
#                'o__Sediment-1',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Gemmatales',
#                'f__Gemmataceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Cyanobacteria',
#                'c__Chloroplast',
#                'o__Stramenopiles',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__TA18',
#                'o__PHOS-HD29',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Lachnospiraceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Cyanobacteria',
#                'c__Chloroplast',
#                'o__Chlorophyta',
#                'f__Chlamydomonadaceae',
#                'g__Oophila',
#                's__amblystomatis']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Lachnospiraceae',
#                'g__Coprococcus',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__vadinHA49',
#                'o__p04_C01',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__TM6',
#                'c__SJA-4',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria',
#                'o__Oceanospirillales',
#                'f__Oceanospirillaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__Bdellovibrionales',
#                'f__Bdellovibrionaceae',
#                'g__Bdellovibrio',
#                's__bacteriovorus']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Betaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__OM190',
#                'o__CL500-15',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Actinobacteria',
#                'c__Acidimicrobiia',
#                'o__Acidimicrobiales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Rhodobacterales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__WS1',
#                'c__',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__TK10',
#                'o__AKYG885',
#                'f__Dolo_23',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__MIZ46',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__OD1']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chlorobi',
#                'c__BSV26',
#                'o__C20',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Pirellulales',
#                'f__Pirellulaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Bacteroidetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Bacteroidetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Dehalococcoidetes',
#                'o__Dehalococcoidales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__DA052',
#                'o__Ellin6513',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Epsilonproteobacteria',
#                'o__Campylobacterales',
# ...
#              {'taxonomy': ['k__Bacteria',
#                'p__OP3',
#                'c__koll11',
#                'o__GIF10',
#                'f__kpj58rc',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria',
#                'o__Xanthomonadales',
#                'f__Sinobacteraceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Actinobacteria',
#                'c__Thermoleophilia',
#                'o__Solirubrobacterales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Bacteroidetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__Flavobacteriia',
#                'o__Flavobacteriales',
#                'f__Flavobacteriaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Bacteroidetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Gemmatales',
#                'f__Gemmataceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__OP3',
#                'c__koll11',
#                'o__GIF10',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Gracilibacteraceae',
#                'g__Gracilibacter',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__Desulfuromonadales',
#                'f__Geobacteraceae',
#                'g__Geobacter',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__TK17',
#                'o__mle1-48',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Pirellulales',
#                'f__Pirellulaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Rhodospirillales',
#                'f__Rhodospirillaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__Myxococcales',
#                'f__Polyangiaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__NB1-j']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__SHA-26',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Verrucomicrobia',
#                'c__[Spartobacteria]',
#                'o__[Chthoniobacterales]',
#                'f__[Chthoniobacteraceae]']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Chlorobi']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Cyanobacteria',
#                'c__Chloroplast',
#                'o__Chlorophyta']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chlorobi',
#                'c__Ignavibacteria',
#                'o__Ignavibacteriales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea',
#                'p__[Parvarchaeota]',
#                'c__[Parvarchaea]',
#                'o__YLA114',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Verrucomicrobia',
#                'c__Verrucomicrobiae',
#                'o__Verrucomicrobiales',
#                'f__Verrucomicrobiaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Cyanobacteria',
#                'c__Chloroplast']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Alphaproteobacteria',
#                'o__Rhodospirillales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Actinobacteria',
#                'c__Actinobacteria',
#                'o__Actinomycetales',
#                'f__Mycobacteriaceae',
#                'g__Mycobacterium',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Deltaproteobacteria',
#                'o__Myxococcales',
#                'f__OM27',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__TM6',
#                'c__SJA-4',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Betaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__Solibacteres',
#                'o__Solibacterales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Proteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Actinobacteria',
#                'c__Thermoleophilia',
#                'o__Solirubrobacterales',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Phycisphaerae',
#                'o__WD2101',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Synergistetes',
#                'c__Synergistia',
#                'o__Synergistales',
#                'f__Dethiosulfovibrionaceae',
#                'g__TG5',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__Cytophagia',
#                'o__Cytophagales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Bacteroidetes',
#                'c__Cytophagia',
#                'o__Cytophagales',
#                'f__Flammeovirgaceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea',
#                'p__[Parvarchaeota]',
#                'c__[Parvarchaea]',
#                'o__YLA114',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__[Chloracidobacteria]',
#                'o__PK29',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria', 'p__Bacteroidetes']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea', 'p__Euryarchaeota']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__GN04',
#                'c__GN15',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Epsilonproteobacteria',
#                'o__Campylobacterales',
#                'f__Helicobacteraceae',
#                'g__Sulfurimonas',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Acidobacteria',
#                'c__AT-s2-57',
#                'o__',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria',
#                'o__Thiotrichales',
#                'f__Piscirickettsiaceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Actinobacteria',
#                'c__Actinobacteria',
#                'o__Actinomycetales']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Firmicutes',
#                'c__Clostridia',
#                'o__Clostridiales',
#                'f__Lachnospiraceae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Proteobacteria',
#                'c__Gammaproteobacteria']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Planctomycetes',
#                'c__Planctomycetia',
#                'o__Gemmatales',
#                'f__Isosphaeraceae',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__Chloroflexi',
#                'c__Anaerolineae']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Bacteria',
#                'p__[Caldithrix]',
#                'c__KSB1',
#                'o__MSB-5B5',
#                'f__',
#                'g__',
#                's__']}),
#  defaultdict(<function biom.table.Table._cast_metadata.<locals>.cast_metadata.<locals>.<lambda>>,
#              {'taxonomy': ['k__Archaea',
#                'p__Euryarchaeota',
#                'c__Methanomicrobia',
#                'o__Methanomicrobiales',
#                'f__Methanospirillaceae']}),
#  ...)

# %%
# loading map file for 2k subset

df = pd.read_csv('../data/emp_qiime_mapping_subset_2k.tsv', sep='\t')
df_soil = df.loc[df['env_material'].isin(['soil'])]
print("Filtered # soil samples based on ENV_material ontology : ",len(df_soil))

# extract sample IDs for soils
ids_soil = df_soil['#SampleID'].tolist()
# Out:
# Filtered # soil samples based on ENV_material ontology :  117

# %%
# table.get_value_by_ids(samp_id = ids_soil)
# table.get_value_by_ids(samp_id = ids_soil)

ids_soil_in_table = set(ids_soil) & (set(table.ids()))
table_soil = table.filter(ids_soil_in_table, axis = 'sample')

# Convert table into relative abundances, normalized within each sample (sum up to 1 column-wise)
normed_soil = table_soil.norm(axis='sample', inplace=False)

# %%
depths = np.sum(table_soil.matrix_data.T.todense(), axis = 1)
plt.hist(depths, bins = 'auto')
plt.xlabel('depth')
plt.ylabel('frequency')
plt.title('Histogram of OTU frequencies')
plt.show()

# %%
# Perform Sparsed-PCA for normalized soil OTU matrix

from sklearn.decomposition import TruncatedSVD
X = normed_soil.matrix_data.T
svd = TruncatedSVD(n_components = 30)
X_new = svd.fit_transform(X)
print("Trancated X (n_samples * m_observations)",X_new.shape)
# 30 features (observations) along add up to more than 90% of the full variance of the data 
print("cummulative explained variance", svd.explained_variance_ratio_.sum())
# Out:
# Trancated X (n_samples * m_observations) (113, 30)
# cummulative explained variance 0.9064346708265324

# %%
import matplotlib.pyplot as plt
cum_explained_var = []
for i in range(0, len(svd.explained_variance_ratio_)):
    if i == 0:
        cum_explained_var.append(svd.explained_variance_ratio_[i])
    else:
        cum_explained_var.append(svd.explained_variance_ratio_[i] + 
                                 cum_explained_var[i-1])
# print(cum_explained_var) 
cmv, = plt.plot(cum_explained_var, 'r^', label = 'cum_explained_var')
evr, = plt.plot(svd.explained_variance_ratio_, 'b.', label = 'explained_variance_ratio')
plt.legend(handles=[cmv, evr])
plt.xlabel('n_components')
plt.ylabel('variance')
plt.title('PCA demonstration on sparse matrix')
plt.show()

# %%
X_new[:,1].shape
# Out:
# (113,)

# %%
# Compute the distance matrix (using cosine similarity for simplicity here)

D = pairwise_distances(X, metric = 'cosine')
D_new = pairwise_distances(X_new, metric = 'cosine')



# print(a.eigvals)
# Out:
# (113, 113) (113, 113)

# %%
from skbio.stats.ordination import pcoa
pcoa(D_new)

# %%
a = pcoa(D_new)
# print(a.eigvals)

# %%
# Use rpy2 to run R within Python

import rpy2
print(rpy2.__version__)
from rpy2.robjects.packages import importr

import rpy2.robjects.numpy2ri
rpy2.robjects.numpy2ri.activate()
# import R's packages
base = importr('base')
utils = importr('utils')
cluster = importr('cluster')
# Out:
# 2.9.2

# %%
num_clusters = 3
p = cluster.pam(D_new,num_clusters)

pc1 = np.log(X_new[:,0])
pc2 = np.log(X_new[:,1])


# print(p[2])
cluster_assignment = np.array(p[2])
# print(cluster_assignment)
idxs = []
for i in range(num_clusters):
    idxs.append(np.where(cluster_assignment == (i+1))[0])
# print(idxs)

plt.scatter(pc1[idxs[0]],pc2[idxs[0]],c='r', marker='+')
plt.scatter(pc1[idxs[1]],pc2[idxs[1]],c='g', marker='^')
plt.scatter(pc1[idxs[2]],pc2[idxs[2]],c='b', marker='o')


plt.xlabel('log of 1st princple component')
plt.ylabel('log of 2nd princple component')
plt.title('3 Clusters by using K-means on cosine distance Matrix')
plt.show()

# %%
# Feature importance by Random Forest model based on cluster result

from sklearn.ensemble import ExtraTreesClassifier

# feature extraction
x = X.todense()
model = ExtraTreesClassifier()
model.fit(x, cluster_assignment)
imp_feat = model.feature_importances_

# %%
# get top 5 important features
top = sorted(range(len(imp_feat)), key=lambda i: imp_feat[i], reverse=True)[:5]
print("important scores:", imp_feat[top])
# Out:
# [0.01831791 0.01690002 0.01672578 0.0155372  0.01228147 0.01193223
#  0.0113244  0.01128751 0.01030554 0.01020991]

# %%
table.metadata(axis = 'observation')[top]['taxonomy']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-6bc759cc271a> in <module>()
# ----> 1 table.metadata(axis = 'observation')[top]
#
# TypeError: tuple indices must be integers or slices, not list

# %%
# Out:
# 113.00000000000013

# %%
# Useful script
# http://biom-format.org/documentation/biom_conversion.html
# http://biom-format.org/documentation/table_objects.html
